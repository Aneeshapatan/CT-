# %%
import numpy as np
import pandas as pd
df1 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv",encoding="ISO-8859-1")
df2 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv",encoding="ISO-8859-1")
df3 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv",encoding="ISO-8859-1")
df4 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv",encoding="ISO-8859-1")
df5 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv",encoding="ISO-8859-1")
df6 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv",encoding="ISO-8859-1")
df7 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv",encoding="ISO-8859-1")
df8 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv",encoding="ISO-8859-1")
df9 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv",encoding="ISO-8859-1")
df10 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv",encoding="ISO-8859-1")
df11 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv",encoding="ISO-8859-1")
df12 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv",encoding="ISO-8859-1")
df13 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv",encoding="ISO-8859-1")
df14 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv",encoding="ISO-8859-1")
df15 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv",encoding="ISO-8859-1")
df16 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv",encoding="ISO-8859-1")
df17 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv",encoding="ISO-8859-1")
df18 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv",encoding="ISO-8859-1")
df19 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv",encoding="ISO-8859-1")
df20 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv",encoding="ISO-8859-1")
df21 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv",encoding="ISO-8859-1")
df22 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv",encoding="ISO-8859-1")
df23 =pd.read_csv(r"C:\Users\DELL\Downloads\DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv",encoding="ISO-8859-1")

# %%
df=pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23])
df
# Out:
#      State Code District Code      India/States Division Group  Class  \
# 0           `21          `000    STATE - ODISHA      `00  `000  `0000
# 1           `21          `000    STATE - ODISHA      `01  `000  `0000
# 2           `21          `000    STATE - ODISHA      `01  `011  `0000
# 3           `21          `000    STATE - ODISHA      `01  `011  `0111
# 4           `21          `000    STATE - ODISHA      `01  `011  `0112
# ...         ...           ...               ...      ...   ...    ...
# 6549        `12          `260  District - Anjaw      `99  `000  `0000
# 6550        `12          `260  District - Anjaw      `99  `991  `0000
# 6551        `12          `260  District - Anjaw      `99  `991  `9910
# 6552        `12          `260  District - Anjaw      `99  `992  `0000
# 6553        `12          `260  District - Anjaw      `99  `992  `9920
#
#                                                NIC Name  \
# 0                                                 Total
# ...

# %%
#remove commas where does not required
df['State Code']=df['State Code'].astype(str).str.replace('`','').astype(int)
df['District Code']=df['District Code'].astype(str).str.replace('`','').astype(int)
df['Division']=df['Division'].astype(str).str.replace('`','').astype(int)
df['Group']=df['Group'].astype(str).str.replace('`','').astype(int)
df['Class']=df['Class'].astype(str).str.replace('`','').astype(int)

# %%
def clean_column_name(column_name):
    column_name = ''.join(e if e.isalnum() or e in ('_', '.') else ' ' for e in column_name)
    column_name = '_'.join(column_name.split())  # Replace spaces with underscores
    return column_name.strip('_.')

df.columns = [clean_column_name(col).lower() for col in df.columns]

# %%
print(df.head())
# Out:
#    state_code  district_code    india_states  division  group  class  \
# 0          21              0  STATE - ODISHA         0      0      0
# 1          21              0  STATE - ODISHA         1      0      0
# 2          21              0  STATE - ODISHA         1     11      0
# 3          21              0  STATE - ODISHA         1     11    111
# 4          21              0  STATE - ODISHA         1     11    112
#
#                                             nic_name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
# 3  Growing of cereals (except rice), leguminous c...
# 4                                    Growing of rice
#
#    main_workers_total_persons  main_workers_total_males  \
# 0                      630079                    447722
# 1                       18891                     13846
# ...

# %%
print(df.shape)
# Out:
# (195145, 25)

# %%
print(df.columns)
# Out:
# Index(['state_code', 'district_code', 'india_states', 'division', 'group',
#        'class', 'nic_name', 'main_workers_total_persons',
#        'main_workers_total_males', 'main_workers_total_females',
#        'main_workers_rural_persons', 'main_workers_rural_males',
#        'main_workers_rural_females', 'main_workers_urban_persons',
#        'main_workers_urban_males', 'main_workers_urban_females',
#        'marginal_workers_total_persons', 'marginal_workers_total_males',
#        'marginal_workers_total_females', 'marginal_workers_rural_persons',
#        'marginal_workers_rural_males', 'marginal_workers_rural_females',
#        'marginal_workers_urban_persons', 'marginal_workers_urban_males',
#        'marginal_workers_urban_females'],
#       dtype='object')

# %%
# Checking data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195145 entries, 0 to 6553
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   state_code                      195145 non-null  int32
#  1   district_code                   195145 non-null  int32
#  2   india_states                    195145 non-null  object
#  3   division                        195145 non-null  int32
#  4   group                           195145 non-null  int32
#  5   class                           195145 non-null  int32
#  6   nic_name                        195145 non-null  object
#  7   main_workers_total_persons      195145 non-null  int64
#  8   main_workers_total_males        195145 non-null  int64
#  9   main_workers_total_females      195145 non-null  int64
#  10  main_workers_rural_persons      195145 non-null  int64
#  11  main_workers_rural_males        195145 non-null  int64
# ...

# %%
print(df.describe())
# Out:
#           state_code  district_code       division          group  \
# count  195145.000000  195145.000000  195145.000000  195145.000000
# mean       19.178278     332.223377      46.590351     389.422404
# std         9.057612     196.176206      28.800311     313.186034
# min         2.000000       0.000000       0.000000       0.000000
# 25%        10.000000     153.000000      23.000000     103.000000
# 50%        19.000000     332.000000      46.000000     370.000000
# 75%        27.000000     516.000000      70.000000     631.000000
# max        34.000000     637.000000      99.000000     992.000000
#
#                class  main_workers_total_persons  main_workers_total_males  \
# count  195145.000000                1.951450e+05              1.951450e+05
# mean     2293.804709                1.492138e+03              1.193171e+03
# std      3059.131669                4.568169e+04              3.773917e+04
# ...

# %%
# Checking for missing values
print(df.isnull().sum())
# Out:
# state_code                        0
# district_code                     0
# india_states                      0
# division                          0
# group                             0
# class                             0
# nic_name                          0
# main_workers_total_persons        0
# main_workers_total_males          0
# main_workers_total_females        0
# main_workers_rural_persons        0
# main_workers_rural_males          0
# main_workers_rural_females        0
# main_workers_urban_persons        0
# main_workers_urban_males          0
# main_workers_urban_females        0
# marginal_workers_total_persons    0
# marginal_workers_total_males      0
# marginal_workers_total_females    0
# marginal_workers_rural_persons    0
# marginal_workers_rural_males      0
# marginal_workers_rural_females    0
# marginal_workers_urban_persons    0
# marginal_workers_urban_males      0
# marginal_workers_urban_females    0
# dtype: int64

# %%
# Finding unique values in categorical columns
print(df['india_states'].unique())
print(df['division'].unique())
print(df['group'].unique())
# Out:
# ['STATE - ODISHA' 'District - Bargarh' 'District - Jharsuguda'
#  'District - Sambalpur' 'District - Debagarh' 'District - Sundargarh'
#  'District - Kendujhar' 'District - Mayurbhanj' 'District - Baleshwar'
#  'District - Bhadrak' 'District - Kendrapara' 'District - Jagatsinghapur'
#  'District - Cuttack' 'District - Jajapur' 'District - Dhenkanal'
#  'District - Anugul' 'District - Nayagarh' 'District - Khordha'
#  'District - Puri' 'District - Ganjam' 'District - Gajapati'
#  'District - Kandhamal' 'District - Baudh' 'District - Subarnapur'
#  'District - Balangir' 'District - Nuapada' 'District - Kalahandi'
#  'District - Rayagada' 'District - Nabarangapur' 'District - Koraput'
#  'District - Malkangiri' 'STATE - NAGALAND' 'District - Mon'
#  'District - Mokokchung' 'District - Zunheboto' 'District - Wokha'
#  'District - Dimapur' 'District - Phek' 'District - Tuensang'
#  'District - Longleng' 'District - Kiphire' 'District - Kohima'
# ...

# %%
#Explanatory data analysis
# Unique values and their counts for categorical columns
print(df['india_states'].value_counts())
print(df['division'].value_counts())
print(df['group'].value_counts())
# Out:
# india_states
# STATE - WEST BENGAL                      749
# STATE - RAJASTHAN                        748
# District - North Twenty Four Parganas    743
# STATE - KARNATAKA                        741
# STATE - TAMIL NADU                       736
#                                         ...
# District - Kaushambi                      12
# District - Mahe                           12
# District - Kannauj                        10
# District - Mainpuri                        9
# District - Baghpat                         4
# Name: count, Length: 491, dtype: int64
# division
# 47    12246
# 1      8356
# 10     7015
# 46     6241
# 85     5553
#       ...
# 70      503
# 98      496
# 0       494
# 92      408
# 39      330
# Name: count, Length: 89, dtype: int64
# group
# 0      31682
# 239     2479
# 14      2250
# 107     2236
# 331     1969
#        ...
# 652       70
# 774       60
# 182       50
# 383       48
# 266       36
# Name: count, Length: 241, dtype: int64

# %%
#Check for correlations between numerical variables to understand relationships.
import seaborn as sns
import matplotlib.pyplot as plt
def correlation_matrix():
    numeric_df = df.select_dtypes(include=['float64','int64'])
    plt.figure(figsize=(12,10))
    sns.heatmap(numeric_df.corr(), annot=True,cmap='coolwarm',fmt='.2f')
    plt.title('correlation_matrix')
    plt.show()
correlation_matrix()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of Total Workers
plt.figure(figsize=(10, 6))
sns.histplot(df['main_workers_total_persons'], kde=True, bins=30, color='blue')
plt.title("Distribution of Main Workers (Total Persons)") # identifying skewness, outliers, and patterns in individual variables.
plt.show()

# Distribution of Marginal Workers
plt.figure(figsize=(10, 6))
sns.histplot(df['marginal_workers_total_persons'], kde=True, bins=30, color='green')
plt.title("Distribution of Marginal Workers (Total Persons)")
plt.show()

# %%
x_var = "marginal_workers_total_persons"
y_var = "main_workers_total_persons"

plt.figure(figsize=(10, 6))

# Scatter plot with regression line and color coding by division
sns.scatterplot(x=df[x_var], y=df[y_var], hue=df['division'], palette='viridis')
sns.regplot(x=df[x_var], y=df[y_var], scatter=False, color='red')  # Adding a regression line

plt.title(f"Scatterplot of {x_var} vs {y_var} with Regression Line")
plt.xlabel("Marginal Workers (Total Persons)")
plt.ylabel("Main Workers (Total Persons)")
plt.show()

# Calculate and display the correlation coefficient
correlation = df[x_var].corr(df[y_var])
print(f"Correlation between {x_var} and {y_var}: {correlation:.2f}")
# Out:
# Correlation between marginal_workers_total_persons and main_workers_total_persons: 0.93

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_var = "main_workers_total_persons"  # Column names should match exactly (case-sensitive)

plt.figure(figsize=(10, 6))
sns.scatterplot(x='state_code', y=y_var, data=df)  # Ensure column names match `df`
plt.xlabel('State Code')
plt.ylabel('Number of Main Workers')
plt.title('State Code vs Main Workers')
plt.show()

# %%
#feature engineering
# Total workers (main + marginal)
df['total_workers_persons'] = df['main_workers_total_persons'] + df['marginal_workers_total_persons']
df['total_workers_males'] = df['main_workers_total_males'] + df['marginal_workers_total_males']
df['total_workers_females'] = df['main_workers_total_females'] + df['marginal_workers_total_females']

# %%
# Male-Female Ratio
df['male_female_ratio'] = df['total_workers_males'] / (df['total_workers_females'] + 1)  # Adding 1 to avoid division by zero

# %%
# Rural-Urban Ratio
df['rural_urban_ratio'] = (
    (df['main_workers_rural_persons'] + df['marginal_workers_rural_persons']) /
    (df['main_workers_urban_persons'] + df['marginal_workers_urban_persons'] + 1)
)

# %%
print(df[['total_workers_persons', 'total_workers_males', 'total_workers_females', 'male_female_ratio', 'rural_urban_ratio']].head())
# Out:
#    total_workers_persons  total_workers_males  total_workers_females  \
# 0                1064141               643659                 420482
# 1                  42292                26014                  16278
# 2                    576                  335                    241
# 3                     90                   63                     27
# 4                     77                   54                     23
#
#    male_female_ratio  rural_urban_ratio
# 0           1.530761           4.801447
# 1           1.598010          11.191698
# 2           1.384298           2.952055
# 3           2.250000           2.640000
# 4           2.250000           5.500000

# %%
# Checking the unique values in the NIC name column
print(df['nic_name'].unique())
# Out:
# ['Total'
#  'Crop and animal production, hunting and related service activities'
#  'Growing of non-perennial crops'
#  'Growing of cereals (except rice), leguminous crops and oil seeds'
#  'Growing of rice' 'Growing of vegetables and melons, roots and tubers'
#  'Growing of sugar cane' 'Growing of tobacco' 'Growing of fibre crops'
#  'Growing of other non-perennial crop' 'Growing of perennial crops'
#  'Growing of tropical and subtropical fruits' 'Growing of citrus fruits'
#  'Growing of pome fruits and stone fruits'
#  'Growing of other tree and bush fruits and nuts'
#  'Growing of oleaginous fruits' 'Growing of beverage crops'
#  'Growing of spices, aromatic, drug and pharmaceutical crops'
#  'Growing of other perennial crops' 'Plant propagation'
#  'Animal production' 'Raising of cattle and buffaloes'
#  'Raising and breeding of camels and camelids'
#  'Raising of sheep and goats' 'Raising of swine/pigs' 'Raising of poultry'
#  'Raising of other animals' 'Mixed farming'
# ...

# %%
# Lowercasing and removing unnecessary spaces
df['nic_name'] = df['nic_name'].str.lower().str.strip()

# %%
# Select only the numerical columns for outlier detection
numerical_columns = [
    'main_workers_total_persons', 'main_workers_total_males', 'main_workers_total_females',
    'main_workers_rural_persons', 'main_workers_rural_males', 'main_workers_rural_females',
    'main_workers_urban_persons', 'main_workers_urban_males', 'main_workers_urban_females',
    'marginal_workers_total_persons', 'marginal_workers_total_males', 'marginal_workers_total_females',
    'marginal_workers_rural_persons', 'marginal_workers_rural_males', 'marginal_workers_rural_females',
    'marginal_workers_urban_persons', 'marginal_workers_urban_males', 'marginal_workers_urban_females',
    'total_workers_persons', 'total_workers_males', 'total_workers_females', 'male_female_ratio','rural_urban_ratio',
]
# Calculate outliers using Z-score
z_scores =df[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Plot Box Plots to visualize the distribution and outliers
plt.figure(figsize=(12, 8))
df[numerical_columns].boxplot()
plt.title("Box Plot of Numerical Columns")
plt.xticks(rotation=90)
plt.show()

# Plot Box Plots separately for each numerical column to focus on individual distributions
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    df[[column]].boxplot()
    plt.title(f"Box Plot of {column}")
    plt.show()

# %%
#Remove outliers
# Select only the numerical columns for outlier detection
numerical_columns = [
    'main_workers_total_persons', 'main_workers_total_males', 'main_workers_total_females',
    'main_workers_rural_persons', 'main_workers_rural_males', 'main_workers_rural_females',
    'main_workers_urban_persons', 'main_workers_urban_males', 'main_workers_urban_females',
    'marginal_workers_total_persons', 'marginal_workers_total_males', 'marginal_workers_total_females',
    'marginal_workers_rural_persons', 'marginal_workers_rural_males', 'marginal_workers_rural_females',
    'marginal_workers_urban_persons', 'marginal_workers_urban_males', 'marginal_workers_urban_females',
    'total_workers_persons', 'total_workers_males', 'total_workers_females', 'male_female_ratio','rural_urban_ratio',
]
# Calculate Z-scores for each numerical column
z_scores = df[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Remove rows with outliers in any numerical column
df_no_outliers = df[~outliers.any(axis=1)]

# Visualize the distribution of cleaned data with Box Plots
plt.figure(figsize=(12, 8))
df_no_outliers = df[~outliers.any(axis=1)]
df_no_outliers[numerical_columns].boxplot()  # Removed the square brackets here
plt.title("Box Plot of Numerical Columns (After Removing Outliers)")
plt.xticks(rotation=90)
plt.show()

# %%
print(df.shape)
# Out:
# (195145, 30)

# %%
print(df.columns)
# Out:
# Index(['state_code', 'district_code', 'india_states', 'division', 'group',
#        'class', 'nic_name', 'main_workers_total_persons',
#        'main_workers_total_males', 'main_workers_total_females',
#        'main_workers_rural_persons', 'main_workers_rural_males',
#        'main_workers_rural_females', 'main_workers_urban_persons',
#        'main_workers_urban_males', 'main_workers_urban_females',
#        'marginal_workers_total_persons', 'marginal_workers_total_males',
#        'marginal_workers_total_females', 'marginal_workers_rural_persons',
#        'marginal_workers_rural_males', 'marginal_workers_rural_females',
#        'marginal_workers_urban_persons', 'marginal_workers_urban_males',
#        'marginal_workers_urban_females', 'total_workers_persons',
#        'total_workers_males', 'total_workers_females', 'male_female_ratio',
#        'rural_urban_ratio', 'cluster'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Selecting the relevant columns
selected_columns = [
    'main_workers_total_persons', 'main_workers_total_males', 'main_workers_total_females',
    'marginal_workers_total_persons', 'marginal_workers_total_males', 'marginal_workers_total_females',
    'total_workers_persons', 'total_workers_males', 'total_workers_females',
    'male_female_ratio', 'rural_urban_ratio'
]
data = df[selected_columns]

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Applying PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# Plotting the PCA results
plt.figure(figsize=(10, 6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c='purple', marker='o', s=100, alpha=0.6)
plt.title('PCA Scatter Plot of Industrial Workforce Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calculate WCSS for different number of clusters
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pca_data)  # Assuming pca_data is your PCA-transformed data
    wcss.append(kmeans.inertia_)  # Inertia is the WCSS

# Plotting the Elbow Graph
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='-', color='blue')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calculating WCSS for different values of K
wcss = []
K_range = range(1, 11)  # You can increase the range if needed

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pca_data)  # Assuming pca_data is your PCA-transformed data
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Plot
plt.figure(figsize=(8, 5))
plt.plot(K_range, wcss, marker='o', linestyle='-', color='purple')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# %%
import numpy as np
import string
import nltk
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.sentiment import SentimentIntensityAnalyzer
from wordcloud import WordCloud

# Download necessary NLTK resources (only once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')  # Required for SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Ensure column is properly formatted
df['nic_name'] = df['nic_name'].astype(str).fillna("")

def clean_and_tokenize(text):
    text = text.lower()  # Convert to lowercase
    text = text.translate(str.maketrans("", "", string.punctuation))  # Remove punctuation
    tokens = word_tokenize(text)  # Tokenization
    stop_words = set(stopwords.words('english'))  # Load stopwords
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return tokens

# Apply function to the column
df['nic_name'] = df['nic_name'].apply(clean_and_tokenize)

# %%
from gensim.models import Word2Vec

# Assuming 'cleaned_tokens' is the column containing tokenized text
sentences = df['nic_name'].tolist()

# Train Word2Vec model
model = Word2Vec(df['nic_name'], vector_size=100, window=5, min_count=1, workers=4)

# Save the Word2Vec model
model.save("word2vec_model")

# You can use the trained Word2Vec model to get word vectors
word_to_check = 'uranium'
word_vector = model.wv[word_to_check]

# %%
word_vector
# Out:
# array([-0.03921589,  0.04575429, -0.06766996,  0.01253361, -0.00040006,
#        -0.13406998, -0.072589  ,  0.11075271, -0.1753689 ,  0.04661328,
#        -0.00886672, -0.04696425,  0.01845771,  0.10401903, -0.00826282,
#        -0.06048618,  0.05759059, -0.11572688, -0.03670579, -0.11573018,
#         0.04405087, -0.02906437,  0.06372052, -0.02393225, -0.00536448,
#         0.06621128, -0.05145526, -0.05208028, -0.01481366,  0.08318511,
#         0.0601396 ,  0.02111936, -0.02647751, -0.1090106 , -0.03607857,
#         0.09149297, -0.06106948,  0.03853611, -0.03014721, -0.16918756,
#         0.01276394, -0.12029654, -0.01586434, -0.00976226,  0.02135941,
#         0.03175838, -0.09122312,  0.04731932,  0.05472555, -0.02496645,
#         0.03992727,  0.00102852,  0.0555231 , -0.02813951,  0.0084256 ,
#        -0.05611719, -0.00942575,  0.07233702,  0.01265424,  0.12294467,
#         0.09840275, -0.09733216,  0.02358591, -0.09059529, -0.0279437 ,
# ...

# %%
print(model)
# Out:
# Word2Vec<vocab=707, vector_size=100, alpha=0.025>

# %%
# Calculate word frequencies
all_tokens = [token for tokens_list in df['nic_name'] for token in tokens_list]
freq_dist = FreqDist(all_tokens)

# Visualize word frequencies using a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dist)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
 # Create a sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Convert the list to a string
df['nic_name_str'] = df['nic_name'].apply(lambda x: ' '.join(map(str, x)))

# Apply sentiment analysis to the new string column
df['sentiment_score'] = df['nic_name_str'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
# Load the Word2Vec model
loaded_model = Word2Vec.load("word2vec_model")

# Check if 'workers' is in the vocabulary
word_to_check = 'grapes' 

word_vector = loaded_model.wv[word_to_check]

# %%
# Get the vocabulary of the Word2Vec model
vocabulary = loaded_model.wv.key_to_index

# Print the first 10 words in the vocabulary
print(list(vocabulary.keys())[:10])
# Out:
# ['activities', 'manufacture', 'products', 'sale', 'retail', 'service', 'nec', 'equipment', 'specialized', 'stores']

# %%
# Check model


from gensim.models import Word2Vec

# Load the Word2Vec model
loaded_model = Word2Vec.load("word2vec_model")

# Check if 'MarginalWorkersRuralMales' is in the vocabulary
word_to_check = 'marginal_workers_rural_males'

if word_to_check in loaded_model.wv:
    print(f"The word '{word_to_check}' is present in the Word2Vec model's vocabulary.")
    # Retrieve the word vector if needed
    word_vector = loaded_model.wv[word_to_check]
    print("Word Vector:", word_vector)
else:
    print(f"The word '{word_to_check}' is not present in the Word2Vec model's vocabulary.")
# Out:
# The word 'marginal_workers_rural_males' is not present in the Word2Vec model's vocabulary.

# %%
# Get the vocabulary of the Word2Vec model
vocabulary = loaded_model.wv.key_to_index

# Print the first 10 words in the vocabulary
print(list(vocabulary.keys())[:10])
# Out:
# ['activities', 'manufacture', 'products', 'sale', 'retail', 'service', 'nec', 'equipment', 'specialized', 'stores']

# %%
df.to_csv("final_GEO.csv", index = False)
